# %%
import numpy as np
import pandas as pd
import os
import h5py as h5
import seaborn as sns
import matplotlib.pyplot as plt

# %%
class FileReader(object):
    def __init__(self, path, class_labels=['city','interurban','highway']):
        self.class_labels = class_labels
        self.path_to_filelist(path)
            
    def path_to_filelist(self, path):
        self.file_list = []
        if os.path.isfile(path=path):
            self.file_list.append(path)
        elif os.path.isdir(path):
            for fn in os.listdir(path):
                self.file_list.append(path + fn)
        
    
    def create_file_frame(self, filename, seed, vocab, approach='nengo', data=[], b_train=False):
        with h5.File(filename, 'r') as hf:
            pred_key='test_enhanced_pred'
            label_key = 'test_enhanced_label'
            if b_train:
                pred_key='train_pred'
                label_key='train_label'
                
            prediction_vecs = np.array(hf[pred_key])
            label = np.argmax(hf[label_key], axis=1)
            prediction = np.argmax(hf[pred_key], axis=1)
            l = np.min([len(label), len(prediction)])
            b_prediction = label[:l] == prediction[:l]
            confidence = prediction_vecs[prediction]
            
            for i in np.arange(l):
                
                dat_dict = dict(true_label=self.class_labels[label[i]], 
                            prediction_label=self.class_labels[prediction[i]], 
                            b_correct_prediction=b_prediction[i],
                            confidence=confidence[i][prediction[i]],
                            seed=seed,
                            vocab=vocab,
                            approach=approach)

                data.append(dat_dict)

        return pd.DataFrame(data), data
    
    def create_plot_frame_from_file_frame(self, file_frame):
        data = []
        for app in np.unique(file_frame['approach']):
            for vocab in np.unique(file_frame.query('approach == "%s"'%app)['vocab']):
                for seed in np.unique(file_frame.query('approach == "%s" and vocab == "%s"'%(app, vocab))['seed']):
                    df = file_frame.query('approach == "%s" and vocab == "%s" and seed == %i'%(app, vocab, seed))
                    dat_dict = dict(
                        approach=app,
                        vocab=vocab,
                        seed=seed,
                        percentage=100*np.sum(df['b_correct_prediction'])/len(df['b_correct_prediction']),
                        label='total'
                        )
                    data.append(dat_dict)
                    
                    for label in self.class_labels:
                        dat_dict = dict(
                            approach=app,
                            vocab=vocab,
                            seed=seed,
                            percentage=100*np.sum(df.query('true_label=="%s"'%label)['b_correct_prediction'])/len(df.query('true_label=="%s"'%label)['b_correct_prediction']),
                            label=label
                        )
                        data.append(dat_dict)
                        
        return pd.DataFrame(data)
    
    def create_analysis_plot_frame_from_file_frame(self, file_frame):
        data = []
        for app in np.unique(file_frame['approach']):
            for vocab in np.unique(file_frame.query('approach == "%s"'%app)['vocab']):
                for seed in np.unique(file_frame.query('approach == "%s" and vocab == "%s"'%(app, vocab))['seed']):
                    df = file_frame.query('approach == "%s" and vocab == "%s" and seed == %i'%(app, vocab, seed))
                    
                    for true_label in self.class_labels:
                        for pred_label in self.class_labels:
#                             print(true_label, pred_label)
                            dat_dict = dict(
                                approach=app,
                                vocab=vocab,
                                seed=seed,
                                percentage=100*len(df.query('true_label=="%s" and prediction_label=="%s"'%(true_label, pred_label))['b_correct_prediction'])/len(df.query('true_label=="%s"'%true_label)['b_correct_prediction']),
                                true_label=true_label,
                                prediction_label=pred_label,
                            )
                            data.append(dat_dict)
                        
        return pd.DataFrame(data)

# %%
fr = FileReader(path='/media/flo/LACIE_HD1/data/512D/')

# %%
data = []
for i, fn in enumerate(fr.file_list):
    df, data = fr.create_file_frame(fn, seed=i, vocab='random_512', approach='nengo', data=data, b_train=False)

# %%
plot_df = fr.create_analysis_plot_frame_from_file_frame(file_frame=df)

# %%
plot_df
# Out:
#    approach  percentage prediction_label  seed  true_label       vocab
# 0     nengo   96.437756             city     0        city  random_512
# 1     nengo    2.734469       interurban     0        city  random_512
# 2     nengo    0.827775          highway     0        city  random_512
# 3     nengo   65.098199             city     0  interurban  random_512
# 4     nengo   29.748571       interurban     0  interurban  random_512
# 5     nengo    5.153230          highway     0  interurban  random_512
# 6     nengo    0.003621             city     0     highway  random_512
# 7     nengo    3.458015       interurban     0     highway  random_512
# 8     nengo   96.538364          highway     0     highway  random_512
# 9     nengo   97.140963             city     1        city  random_512
# 10    nengo    1.265772       interurban     1        city  random_512
# 11    nengo    1.593265          highway     1        city  random_512
# 12    nengo   65.109279             city     1  interurban  random_512
# 13    nengo   29.192713       interurban     1  interurban  random_512
# 14    nengo    5.698008          highway     1  interurban  random_512
# 15    nengo    1.165949             city     1     highway  random_512
# 16    nengo    2.643299       interurban     1     highway  random_512
# 17    nengo   96.190752          highway     1     highway  random_512
# 18    nengo   97.134935             city     2        city  random_512
# 19    nengo    1.623403       interurban     2        city  random_512
# 20    nengo    1.241662          highway     2        city  random_512
# 21    nengo   67.272694             city     2  interurban  random_512
# 22    nengo   24.455915       interurban     2  interurban  random_512
# 23    nengo    8.271392          highway     2  interurban  random_512
# 24    nengo    0.121302             city     2     highway  random_512
# 25    nengo    2.053083       interurban     2     highway  random_512
# 26    nengo   97.825615          highway     2     highway  random_512
# 27    nengo   95.376919             city     3        city  random_512
# 28    nengo    2.929358       interurban     3        city  random_512
# 29    nengo    1.693723          highway     3        city  random_512
# ..      ...         ...              ...   ...         ...         ...
# 60    nengo    1.017489             city     6     highway  random_512
# 61    nengo    0.733244       interurban     6     highway  random_512
# 62    nengo   98.249267          highway     6     highway  random_512
# 63    nengo   97.191192             city     7        city  random_512
# 64    nengo    1.920759       interurban     7        city  random_512
# 65    nengo    0.888050          highway     7        city  random_512
# 66    nengo   68.583854             city     7  interurban  random_512
# 67    nengo   23.589810       interurban     7  interurban  random_512
# 68    nengo    7.826336          highway     7  interurban  random_512
# 69    nengo    0.010863             city     7     highway  random_512
# 70    nengo    3.678893       interurban     7     highway  random_512
# 71    nengo   96.310244          highway     7     highway  random_512
# 72    nengo   96.076107             city     8        city  random_512
# 73    nengo    2.354738       interurban     8        city  random_512
# 74    nengo    1.569155          highway     8        city  random_512
# 75    nengo   67.895957             city     8  interurban  random_512
# 76    nengo   25.337716       interurban     8  interurban  random_512
# 77    nengo    6.766327          highway     8  interurban  random_512
# 78    nengo    0.177427             city     8     highway  random_512
# 79    nengo    1.091719       interurban     8     highway  random_512
# 80    nengo   98.730854          highway     8     highway  random_512
# 81    nengo   95.989713             city     9        city  random_512
# 82    nengo    3.168448       interurban     9        city  random_512
# 83    nengo    0.841839          highway     9        city  random_512
# 84    nengo   59.754758             city     9  interurban  random_512
# 85    nengo   31.236092       interurban     9  interurban  random_512
# 86    nengo    9.009150          highway     9  interurban  random_512
# 87    nengo    3.733208             city     9     highway  random_512
# 88    nengo    5.145381       interurban     9     highway  random_512
# 89    nengo   91.121411          highway     9     highway  random_512
#
# [90 rows x 6 columns]

# %%
sns.set_style("darkgrid")
sns.set(font_scale=2)
fig = plt.figure(figsize=(15,8))
ax = sns.barplot(x='true_label', y='percentage', hue='prediction_label', data=plot_df, capsize=0.2)
# ax.set_title('distances to closest vehicle')
# ax2[1].set_title('distances to ego-vehicle')
ax.set_xlabel('True driving context label')
ax.set_ylabel('Predictions (%)')
ax.legend(title='Predicted label', frameon=True)
# ax.set_ylim([20,100])
plt.tight_layout()
plt.savefig('/home/flo/git/diss/thesis/imgs/context_class_prediction_vs_true_label.eps', dpi=1200)
plt.show()

# %%
del data
