# %%
import numpy as np
import h5py as h5
import seaborn as sns
import pandas as pd
import nengo
import nengo_spa as spa

# %%
hf = h5.File('/media/flo/LACIE_HD/structured_vocabs/rdarius_original/visual_output.h5', 'r')
hf1 = h5.File('/media/flo/LACIE_HD/structured_vocabs/gtsrb_data.h5', 'r')

# %%
keys = list(hf.keys())

# %%
d = {}
for k in keys:
    d[k] = np.array(hf[k])

# %%
list(hf1.keys())
# Out:
# ['test_data', 'test_labels', 'train_data', 'train_labels']

# %%
d['test_labels'] = np.array(hf1['test_labels'])

# %%
d.keys()
# Out:
# dict_keys(['class_names', 'confidence', 'prediction', 'visual_vectors', 'test_labels'])

# %%
mask = d['prediction'] == d['test_labels']

# %%
np.where(~mask)[0]
# Out:
# array([   39,    50,   114,   127,   176,   339,   374,   421,   459,
#          461,   492,   537,   550,   806,   951,  1079,  1200,  1317,
#         1352,  1462,  1475,  1489,  1524,  1560,  1583,  1597,  1689,
#         1745,  1759,  1763,  1774,  1898,  1910,  1918,  2002,  2017,
#         2076,  2109,  2154,  2258,  2332,  2370,  2376,  2388,  2482,
#         2494,  2577,  2682,  2751,  2776,  2836,  2886,  2980,  3052,
#         3086,  3137,  3523,  3564,  3593,  3660,  3704,  3727,  3744,
#         3778,  3819,  3860,  3930,  3960,  4011,  4072,  4115,  4147,
#         4185,  4219,  4271,  4314,  4316,  4341,  4383,  4443,  4601,
#         4617,  4634,  4702,  4739,  4783,  4953,  4983,  5182,  5476,
#         5507,  5518,  5521,  5529,  5547,  5625,  5637,  5641,  5675,
#         5924,  6028,  6087,  6090,  6129,  6155,  6177,  6213,  6220,
#         6255,  6310,  6321,  6334,  6356,  6418,  6469,  6600,  6613,
#         6731,  6739,  6782,  6874,  6889,  6893,  6920,  6941,  6960,
#         6980,  6991,  7081,  7085,  7088,  7142,  7147,  7157,  7258,
#         7276,  7330,  7421,  7525,  7571,  7597,  7680,  7693,  7695,
#         7756,  7840,  7886,  7928,  7949,  7957,  8007,  8187,  8208,
#         8278,  8308,  8309,  8332,  8344,  8352,  8355,  8421,  8460,
#         8499,  8510,  8549,  8587,  8624,  8679,  8702,  8750,  8895,
#         8949,  9087,  9095,  9243,  9267,  9270,  9350,  9411,  9659,
#         9687,  9792,  9835,  9961, 10015, 10030, 10067, 10078, 10137,
#        10173, 10204, 10205, 10230, 10292, 10324, 10359, 10398, 10401,
#        10482, 10524, 10546, 10573, 10584, 10586, 10596, 10708, 10713,
#        10866, 11016, 11036, 11070, 11128, 11132, 11170, 11173, 11178,
#        11212, 11238, 11324, 11391, 11392, 11409, 11438, 11465, 11520,
#        11543, 11564, 11616, 11625, 11741, 11756, 11762, 11817, 11825,
#        11866, 11908, 12024, 12032, 12040, 12111, 12120, 12153, 12155,
#        12215, 12226, 12227, 12276, 12339, 12346, 12354, 12369, 12396,
#        12412, 12479, 12481])

# %%
ind_list = []
for c in np.arange(43):
    inds = np.where(d['test_labels'] == c)[0]
    correct_inds = np.where(d['prediction'][inds] == d['test_labels'][inds])[0]
    high_conf_inds = np.where(d['confidence'][inds][correct_inds] == 1.0)[0]
    final = inds[correct_inds][high_conf_inds]
    ind_list.append(final)

# %%
hf2 = h5.File('/media/flo/LACIE_HD/structured_vocabs/rdarius_original/traffic_sign_complete_vocab.h5', 'r')

# %%
vocab = spa.Vocabulary(dimensions=300)

# %%
list(hf2.keys())
# Out:
# ['semantic_vocab_keys',
#  'semantic_vocab_vectors',
#  'vis_sem_vocab_keys',
#  'vis_sem_vocab_vectors',
#  'visual_vocab_keys',
#  'visual_vocab_vectors']

# %%
vecs = np.array(hf2['semantic_vocab_vectors'])

# %%
for i in np.arange(43):
    vocab.add(key=str(d['class_names'][i].decode()), p=vecs[i])

# %%
data = []
for i in np.arange(43):
    vis_vecs = d['visual_vectors'][ind_list[i]]
    for j, vec in enumerate(vis_vecs):
        dic = dict(sign=i,
                   similarity=vocab[str(d['class_names'][i].decode())].compare(spa.SemanticPointer(vec)))
        data.append(dic)
df = pd.DataFrame(data)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
fig = plt.figure(figsize=(16,10))
sns.set_style("whitegrid")
ax = sns.boxplot(x='sign', y='similarity', data=df)
ax.axhline(2./np.sqrt(300), c='k', ls=':', label='weak similarity threshold')
ax.axhline(3./np.sqrt(300), c='m', ls=':', label='strong similarity threshold')
# replace x-ticks with corresponding imgs
size=0.03
xl, yl, xh, yh=np.array(ax.get_position()).ravel()
xl+= 0.003
xh-= size
w=xh-0.095
h=yh-yl
ax.set_xticklabels(['']*43, fontsize=14)
ax.set_yticklabels(ax.get_yticks(), fontsize=14)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ax.set_ylabel('Similarity', fontsize=20)
# ax.grid(ls=':', alpha=0.5, c='k')
for ind in np.arange(43):
    
    img=plt.imread('../imgs//TrafficSigns/%s.png'%(str(ind).zfill(2)))
    xp=xl+w*((ind)/43) #if replace '0' label, can also be calculated systematically using xlim()
    yp=yl-size*0.5-0.02
    # ax.bar(np.arange(43), acc)
    ax1=fig.add_axes([xp-size*0.3, yp, size, size])
    ax1.axison = False
    imgplot = ax1.imshow(img)
ax.legend(loc='best', fontsize=16)
plt.show()

# %%
sims = np.zeros((43,43))
mask = np.zeros((43,43))
for i in np.arange(43):
    for j in np.arange(43):
        sims[i,j] = vocab[str(d['class_names'][i].decode())].compare(vocab[str(d['class_names'][j].decode())])
#         if j >= i:
#             mask = True

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter
from matplotlib import cm
mask = np.zeros_like(sims)
mask[np.triu_indices_from(mask, k=1)] = True
fig = plt.figure(figsize=(16,14))
ax = sns.heatmap(sims, mask=mask, annot=True, annot_kws={"size": 6}, 
                 cmap=cm.viridis, linewidths=0.2, 
                 cbar_kws={"label": "Similarity", "shrink":0.95})
ax.figure.axes[-1].yaxis.label.set_size(22)
cax = plt.gcf().axes[-1]
cax.tick_params(labelsize=16)
ax.set_xticklabels(['']*43, fontsize=14)
ax.set_yticklabels(['']*43, fontsize=14)
size=0.02
xl, yl, xh, yh=np.array(ax.get_position()).ravel()
xl+= 0.003
xh-= size
w=xh-0.1
h=yh-0.12
for ind in np.arange(43):
    img=plt.imread('../imgs//TrafficSigns/%s.png'%(str(ind).zfill(2)))
    img2=plt.imread('../imgs//TrafficSigns/%s.png'%(str(42-ind).zfill(2)))
    xp=xl+w*((ind)/43) #if replace '0' label, can also be calculated systematically using xlim()
    yp=yl-size*0.4-0.02
    # ax.bar(np.arange(43), acc)
    ax1=fig.add_axes([xp-size*0.3, yp, size, size])
    ax1.axison = False
    xp=xl-size-0.01
    yp=yl+h*((ind)/43)
    ax2=fig.add_axes([xp, yp-size*0.3, size, size])
    ax2.axison = False
    imgplot = ax1.imshow(img)
    imgplot2 = ax2.imshow(img2)
plt.savefig('/home/flo/git/diss/thesis/imgs/semantic_vocab_traffic_signs_internal_similarities.eps', dpi=1200)
plt.show()

# %%
vocab['MAX_TWENTY'].v
# Out:
# array([-0.07335252, -0.02847588, -0.0683981 , -0.03980362, -0.08100344,
#        -0.00980318,  0.10340432, -0.0707477 , -0.10018163, -0.0199324 ,
#         0.01979237,  0.02535598,  0.06402955, -0.05168542, -0.02511648,
#        -0.12353679,  0.02537098,  0.01295343,  0.01570654,  0.11570508,
#         0.05148307, -0.00279726, -0.0418041 , -0.02240266,  0.15510308,
#        -0.04611366,  0.09898053,  0.01364551,  0.03641797, -0.01997736,
#         0.06956738,  0.05344402,  0.06846096,  0.08028575,  0.03983735,
#        -0.00748897,  0.03034706, -0.10489763, -0.0492619 , -0.04341833,
#        -0.06104392, -0.06302095,  0.07014419, -0.02580164,  0.05603363,
#        -0.08180718, -0.08467457, -0.02544487, -0.01776522, -0.04899614,
#        -0.07164105,  0.09265409, -0.04840062, -0.06917221, -0.03866416,
#        -0.03064956,  0.02346929, -0.0061842 ,  0.0399158 ,  0.10112642,
#         0.06948179,  0.0283232 , -0.05439711,  0.08009412,  0.00847611,
#         0.02037956,  0.08437501,  0.00148427,  0.01859861,  0.02143725,
#         0.13707463,  0.05988052, -0.04687521, -0.07633689, -0.09939949,
#         0.03926193,  0.12514121,  0.01328668,  0.07416668,  0.03459871,
#         0.02569289, -0.01892468,  0.05224918, -0.00916874,  0.01082704,
#         0.03835968,  0.0499039 , -0.02864262, -0.06312597, -0.10009326,
#        -0.19154583, -0.04020332, -0.00817506,  0.06794076, -0.06085208,
#        -0.00443459, -0.00846499,  0.05564343,  0.00212871,  0.03022872,
#        -0.08056396, -0.06861398, -0.05609558,  0.05974677,  0.05368758,
#         0.06834724, -0.09160022, -0.02712068,  0.00888073,  0.02988482,
#         0.03172126, -0.02210582, -0.0680082 , -0.01639537,  0.0320866 ,
#        -0.01239985,  0.06603612, -0.00932132,  0.05309739, -0.06719583,
#        -0.05883895, -0.06845036,  0.11640898, -0.08139734, -0.04101558,
#        -0.05918785,  0.05130856,  0.02045401, -0.12968953, -0.08498732,
#        -0.02737278,  0.03788583, -0.00884005,  0.02333021,  0.06628301,
#         0.01744239, -0.0363842 , -0.06088385, -0.02223208, -0.01583276,
#        -0.01163613,  0.02869652,  0.00920158,  0.0481821 ,  0.08486481,
#        -0.06968592, -0.06072271, -0.03397194,  0.0367601 ,  0.0749838 ,
#         0.02308943, -0.01538615,  0.00411798, -0.04433453,  0.01598129,
#         0.1064478 ,  0.04271893,  0.07091098, -0.02400395, -0.02645039,
#         0.15250928,  0.0226769 ,  0.05740549, -0.02978868,  0.07508575,
#        -0.10337268,  0.07214065,  0.0177964 , -0.0115395 , -0.11064398,
#         0.07053464,  0.09498786,  0.0981775 , -0.0168454 , -0.03981341,
#         0.01261116,  0.02916201,  0.08452718, -0.00525861, -0.05533948,
#        -0.02218429,  0.05093096,  0.01985239, -0.04831232, -0.12605231,
#        -0.05029651, -0.06602565, -0.10026622, -0.07645902, -0.00760619,
#        -0.03767016, -0.0383331 ,  0.05844914,  0.05962383,  0.03910068,
#         0.01179685,  0.06429306, -0.03114377,  0.02660778,  0.03332338,
#         0.01068509, -0.01721564, -0.10487774,  0.02507733, -0.09716562,
#         0.02565945, -0.1006755 , -0.07235967, -0.06463024, -0.0173617 ,
#        -0.03013618, -0.05528058,  0.05015577, -0.08060655, -0.03646291,
#        -0.04216371, -0.02884737, -0.00667991,  0.03533049,  0.05576481,
#         0.03938584,  0.00808408,  0.0405355 ,  0.09840801, -0.07116716,
#         0.09917943, -0.02246979,  0.04033755, -0.02251834,  0.03338419,
#         0.00024731, -0.00116368, -0.06887352,  0.10665906, -0.00836675,
#        -0.028608  , -0.09070829,  0.04270167,  0.04823409,  0.03801158,
#        -0.0339099 ,  0.05469657,  0.06373037,  0.09441241, -0.06452862,
#        -0.07818474,  0.00780967,  0.00992834,  0.07950627,  0.03245979,
#        -0.04582332, -0.03883016,  0.06965793, -0.04505855,  0.0394224 ,
#        -0.05596396,  0.02148867, -0.00617998,  0.02335055, -0.0275994 ,
#        -0.01065336, -0.05034132,  0.03442739, -0.05079117, -0.00184059,
#        -0.14939791,  0.02584953, -0.03818562, -0.01721365,  0.05732896,
#        -0.02713653, -0.0609284 , -0.03799705, -0.00440037,  0.02505994,
#         0.00183482,  0.05289486,  0.07846923,  0.01218044,  0.01242966,
#         0.02674936, -0.01372282, -0.0278947 ,  0.07790358, -0.00083004,
#        -0.01276836, -0.05184012,  0.08288918,  0.00374266,  0.00154594,
#        -0.01838981,  0.06376023,  0.04896165,  0.04514912,  0.00500183,
#         0.00500609,  0.0582236 , -0.02155235, -0.0848682 ,  0.02631967])
